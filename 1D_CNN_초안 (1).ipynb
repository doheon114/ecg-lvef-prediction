# %%
# 데이터 분석 라이브러리
import numpy as np
import pandas as pd

# 시각화 라이브러리
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# 딥러닝 라이브러리
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
print(tf.__version__)
# Out:
# 2.17.0-rc1

# %%
import pandas as pd
import numpy as np

# 훈련 데이터 파일 경로
training_file = '/Users/doheonkim/Desktop/dataset/chungnam_training.xlsx'

# 엑셀 파일 로드
training_data = pd.read_excel(training_file)

# 사용할 열 지정
ecg_columns = ['ECG_I', 'ECG_aVL', 'ECG_V1','ECG_V5', 'ECG_V6']

# 각 셀의 데이터를 콤마로 구분하여 배열로 변환하고 결합
X_train = np.array([np.concatenate([np.fromstring(row[col], sep=',')[np.newaxis, :] for col in ecg_columns], axis=0) for _, row in training_data.iterrows()])

# X_train의 모양을 확인
print("X_train shape:", X_train.shape)  # 예상 출력: (467, 5, 249)

# LVEF 값을 기준으로 y_train 레이블 생성
def get_label(lvef):
    if lvef <= 40:
        return 0
    elif 41 <= lvef <= 49:
        return 1
    else:
        return 2

y_train = training_data['LVEF'].apply(get_label).values

# y_train의 모양을 확인
print("y_train shape:", y_train.shape)  # 예상 출력: (467,)
# Out:
# X_train shape: (467, 5, 249)
# y_train shape: (467,)

# %%
import pandas as pd
import numpy as np

# 훈련 데이터 파일 경로
tuning_file = '/Users/doheonkim/Desktop/dataset/chungnam_tuning.xlsx'

# 엑셀 파일 로드
tuning_data = pd.read_excel(tuning_file)

# 사용할 열 지정
ecg_columns = ['ECG_I', 'ECG_aVL', 'ECG_V1','ECG_V5', 'ECG_V6']
# 각 셀의 데이터를 콤마로 구분하여 배열로 변환하고 결합
X_tuning = np.array([np.concatenate([np.fromstring(row[col], sep=',')[np.newaxis, :] for col in ecg_columns], axis=0) for _, row in tuning_data.iterrows()])

print("X_tuning shape:", X_tuning.shape)  

def get_label(lvef):
    if lvef <= 40:
        return 0
    elif 41 <= lvef <= 49:
        return 1
    else:
        return 2

y_tuning = tuning_data['LVEF'].apply(get_label).values

print("y_train shape:", y_tuning.shape)
# Out:
# X_tuning shape: (156, 5, 249)
# y_train shape: (156,)

# %%
import pandas as pd
import numpy as np

# 훈련 데이터 파일 경로
internal_validation_file = '/Users/doheonkim/Desktop/dataset/chungnam_internal_validation.xlsx'

# 엑셀 파일 로드
internal_validation_data = pd.read_excel(internal_validation_file)

# 사용할 열 지정
ecg_columns = ['ECG_I', 'ECG_aVL', 'ECG_V1','ECG_V5', 'ECG_V6']
# 각 셀의 데이터를 콤마로 구분하여 배열로 변환하고 결합
X_internal_validation = np.array([np.concatenate([np.fromstring(row[col], sep=',')[np.newaxis, :] for col in ecg_columns], axis=0) for _, row in internal_validation_data.iterrows()])

print("X_internal_validation shape:", X_internal_validation.shape)  

def get_label(lvef):
    if lvef <= 40:
        return 0
    elif 41 <= lvef <= 49:
        return 1
    else:
        return 2

y_internal_validation = internal_validation_data['LVEF'].apply(get_label).values

print("y_internal_validation shape:", y_internal_validation.shape)
# Out:
# X_internal_validation shape: (155, 5, 249)
# y_internal_validation shape: (155,)

# %%
import matplotlib.pyplot as plt

# 히스토그램 분포 시각화 
plt.hist(y_train, bins=[-0.5, 0.5, 1.5, 2.5], edgecolor='black')
plt.xticks([0, 1, 2])
plt.xlabel('LVEF category')
plt.ylabel('Frequency')
plt.title('train LVEF distribution histogram')
plt.show()

# 히스토그램 분포 시각화 
plt.hist(y_tuning, bins=[-0.5, 0.5, 1.5, 2.5], edgecolor='black')
plt.xticks([0, 1, 2])
plt.xlabel('LVEF category')
plt.ylabel('Frequency')
plt.title('tuning LVEF distribution histogram')
plt.show()

# 히스토그램 분포 시각화 
plt.hist(y_internal_validation, bins=[-0.5, 0.5, 1.5, 2.5], edgecolor='black')
plt.xticks([0, 1, 2])
plt.xlabel('LVEF category')
plt.ylabel('Frequency')
plt.title('internal valid LVEF distribution histogram')
plt.show()

# %%
X_train = X_train.transpose(0, 2, 1)
X_tuning = X_tuning.transpose(0, 2, 1)
X_internal_validation = X_internal_validation.transpose(0, 2, 1)

# %%
import tensorflow as tf

y_train = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_tuning = tf.keras.utils.to_categorical(y_tuning, num_classes=3)

# %%
import tensorflow as tf

lr = 0.001
optimizer = tf.keras.optimizers.Adam(lr)
loss_fn = tf.keras.losses.CategoricalCrossentropy() 
metrics = [tf.keras.metrics.CategoricalAccuracy()]
epochs = 100
batch_size = 32

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv1D(10, kernel_size=1, input_shape=(X_train.shape[1], X_train.shape[2]), activation="relu"))
model.add(tf.keras.layers.MaxPooling1D(pool_size=3))
model.add(tf.keras.layers.Conv1D(20, kernel_size=3, activation="relu"))
model.add(tf.keras.layers.MaxPooling1D(pool_size=3))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(3, activation="softmax"))  

#shape(1000, 4)

### 정의한 모델 컴파일
model.compile(optimizer=optimizer, loss=loss_fn, metrics=metrics)

### 정의한 모델 요약
model.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 249, 10)        │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 83, 10)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 81, 20)         │           620 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 27, 20)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 540)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │         1,623 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,303 (9.00 KB)
#  Trainable params: 2,303 (9.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 콜백 정의
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
model_checkpoint = ModelCheckpoint("best_model.keras", save_best_only=True, monitor='val_categorical_accuracy', mode='max')

# 모델 훈련
history = model.fit(X_train, 
                    y_train, 
                    batch_size=batch_size, 
                    epochs=epochs, 
                    validation_data=(X_tuning, y_tuning), 
                    callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.5059 - loss: 1.0234 - val_categorical_accuracy: 0.4615 - val_loss: 1.0055
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5732 - loss: 0.9681 - val_categorical_accuracy: 0.4615 - val_loss: 1.0168
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5444 - loss: 0.9782 - val_categorical_accuracy: 0.4615 - val_loss: 1.0340
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5746 - loss: 0.9392 - val_categorical_accuracy: 0.4615 - val_loss: 1.0251
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5856 - loss: 0.9063 - val_categorical_accuracy: 0.4615 - val_loss: 1.0308
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5618 - loss: 0.9132 - val_categorical_accuracy: 0.4615 - val_loss: 1.0454
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5633 - loss: 0.9273 - val_categorical_accuracy: 0.4615 - val_loss: 1.0338
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5808 - loss: 0.8938 - val_categorical_accuracy: 0.4551 - val_loss: 1.0421
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5776 - loss: 0.8866 - val_categorical_accuracy: 0.4551 - val_loss: 1.0404
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5935 - loss: 0.8740 - val_categorical_accuracy: 0.4936 - val_loss: 1.0162
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5698 - loss: 0.9093 - val_categorical_accuracy: 0.4615 - val_loss: 1.0831
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5809 - loss: 0.8662 - val_categorical_accuracy: 0.4679 - val_loss: 1.0207
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6130 - loss: 0.8504 - val_categorical_accuracy: 0.4487 - val_loss: 1.0610
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5962 - loss: 0.8635 - val_categorical_accuracy: 0.4615 - val_loss: 1.0485
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6078 - loss: 0.8342 - val_categorical_accuracy: 0.4744 - val_loss: 1.0318
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.6465 - loss: 0.8140 - val_categorical_accuracy: 0.4487 - val_loss: 1.0967
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6192 - loss: 0.7996 - val_categorical_accuracy: 0.4615 - val_loss: 1.0602
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6401 - loss: 0.8127 - val_categorical_accuracy: 0.4551 - val_loss: 1.0723
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6275 - loss: 0.7815 - val_categorical_accuracy: 0.4551 - val_loss: 1.0621
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6522 - loss: 0.7827 - val_categorical_accuracy: 0.4744 - val_loss: 1.0512
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6180 - loss: 0.8391 - val_categorical_accuracy: 0.4551 - val_loss: 1.0954
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6243 - loss: 0.8124 - val_categorical_accuracy: 0.4615 - val_loss: 1.1042
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6621 - loss: 0.7334 - val_categorical_accuracy: 0.4679 - val_loss: 1.0859
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6401 - loss: 0.7610 - val_categorical_accuracy: 0.4551 - val_loss: 1.0837
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6510 - loss: 0.7739 - val_categorical_accuracy: 0.4615 - val_loss: 1.1151
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6933 - loss: 0.7205 - val_categorical_accuracy: 0.4551 - val_loss: 1.0910
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6902 - loss: 0.7289 - val_categorical_accuracy: 0.4679 - val_loss: 1.1363
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6403 - loss: 0.7561 - val_categorical_accuracy: 0.4679 - val_loss: 1.1475
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6632 - loss: 0.7183 - val_categorical_accuracy: 0.4231 - val_loss: 1.1357
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7089 - loss: 0.7234 - val_categorical_accuracy: 0.4679 - val_loss: 1.1030
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6744 - loss: 0.7404 - val_categorical_accuracy: 0.4423 - val_loss: 1.2766
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6566 - loss: 0.7479 - val_categorical_accuracy: 0.4487 - val_loss: 1.1427
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6836 - loss: 0.7045 - val_categorical_accuracy: 0.4295 - val_loss: 1.1683
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7333 - loss: 0.6622 - val_categorical_accuracy: 0.4679 - val_loss: 1.1464
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7038 - loss: 0.6428 - val_categorical_accuracy: 0.4423 - val_loss: 1.1743
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7208 - loss: 0.6748 - val_categorical_accuracy: 0.4359 - val_loss: 1.2170
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7128 - loss: 0.6701 - val_categorical_accuracy: 0.4487 - val_loss: 1.1657
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.7289 - loss: 0.6381 - val_categorical_accuracy: 0.4808 - val_loss: 1.1877
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7423 - loss: 0.6568 - val_categorical_accuracy: 0.4423 - val_loss: 1.2455
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7166 - loss: 0.6445 - val_categorical_accuracy: 0.4295 - val_loss: 1.2824
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6817 - loss: 0.6749 - val_categorical_accuracy: 0.4615 - val_loss: 1.2109
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.7531 - loss: 0.6246 - val_categorical_accuracy: 0.4551 - val_loss: 1.2434
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7407 - loss: 0.6262 - val_categorical_accuracy: 0.4487 - val_loss: 1.2366
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7393 - loss: 0.6173 - val_categorical_accuracy: 0.4551 - val_loss: 1.2360
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7571 - loss: 0.5954 - val_categorical_accuracy: 0.4487 - val_loss: 1.2631
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.7401 - loss: 0.6076 - val_categorical_accuracy: 0.4615 - val_loss: 1.2590
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7426 - loss: 0.5940 - val_categorical_accuracy: 0.4423 - val_loss: 1.2860
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7519 - loss: 0.6063 - val_categorical_accuracy: 0.4551 - val_loss: 1.3045
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7591 - loss: 0.5752 - val_categorical_accuracy: 0.4615 - val_loss: 1.2835
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.8131 - loss: 0.5698 - val_categorical_accuracy: 0.4551 - val_loss: 1.2542
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.7792 - loss: 0.5807 - val_categorical_accuracy: 0.4487 - val_loss: 1.3209

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# 가장 성능이 좋은 모델을 불러오기
model = tf.keras.models.load_model("best_model.keras")

# 학습 결과 시각화
plt.plot(history.history['categorical_accuracy'], label='Train Accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='tuning Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# 테스트 데이터로 예측 수행 및 정확도 평가
y_pred = model.predict(X_internal_validation)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = y_internal_validation

accuracy = np.sum(y_pred_classes == y_true) / len(y_true)
print(f'Accuracy: {accuracy:.2f}')

# 혼동 행렬 시각화
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Accuracy: 0.45
